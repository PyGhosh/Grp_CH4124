# %% [markdown]
# # Exercise 1: Linear and Logistic Regression with Error Estimation

# %% [markdown]
# ## Instructions

# %% [markdown]
# ### Setup check
#
# Run the cell below before you begin. Every entry should report `found`.

# %%
import os
import sys

print("Python", sys.version.split()[0])

for package in ["numpy", "pandas", "matplotlib", "seaborn", "sklearn"]:
    try:
        __import__(package)
        print(f"{package:<12} found")
    except ImportError:
        print(f"{package:<12} MISSING  ->  pip install {package}")

for filename in ["headbrain.csv", "titanic.csv", "diabetes.csv"]:
    path = os.path.join("datasets", filename)
    status = "found" if os.path.isfile(path) else "MISSING" 
    print(f"{filename:<16} {status}")
# Out:
# Python 3.12.4
# numpy        found
# pandas       found
# matplotlib   found
# seaborn      found
# sklearn      found
# headbrain.csv    found
# titanic.csv      found
# diabetes.csv     found

# %% [markdown]
# ---
# # Part A. Linear regression
#
# ## Program 1. Ordinary least squares regression, from first principles and with `scikit-learn`
#
# ### Aim
#
# To implement simple linear regression in Python without a machine learning library, to reproduce
# the same fit using `scikit-learn`, and to attach an uncertainty estimate to the fitted
# coefficients.

# %% [markdown]
# ### Theory
#
# The regression line is written as $y = b_0 + b_1 x$. The least squares estimates of the two
# coefficients are
#
# $$
# \newcommand{\vect}{\mathbf}
# \begin{align}
# b_1 &= \frac{\displaystyle \sum_{i=1}^{m}(x_i-\bar{x})(y_i-\bar{y})}{\displaystyle \sum_{i=1}^{m}(x_i-\bar{x})^2}
# = \frac{(\vect{x}-\bar{x})^T(\vect{y}-\bar{y})}{(\vect{x}-\bar{x})^T(\vect{x}-\bar{x})}
# \\
# b_0 &= \bar{y}-b_1\bar{x}
# \end{align}
# $$
#
# The quality of the fit is summarised by
#
# $$
# \begin{align}
# \text{RMSE} &= \sqrt{\frac{1}{m}\sum_{i=1}^{m}(y_i-\hat{y_i})^2}
# = \sqrt{\frac{(\vect{y}-\hat{\vect{y}})^T(\vect{y}-\hat{\vect{y}})}{m}}
# \\
# \text{SS}_{\text{tot}} &= \sum_{i=1}^{m}(y_i - \bar{y})^2 = (\vect{y}-\bar{y})^T(\vect{y}-\bar{y})
# \\
# \text{SS}_{\text{res}} &= \sum_{i=1}^{m}(y_i - \hat{y}_i)^2 = (\vect{y}-\hat{\vect{y}})^T(\vect{y}-\hat{\vect{y}})
# \\
# R^{2} &= 1-\frac{\text{SS}_{\text{res}}}{\text{SS}_{\text{tot}}}
# \end{align}
# $$
#
# where $\vect{x} = (x_1,x_2,\dots,x_m)$ is the input vector, $\vect{y} = (y_1,y_2,\dots,y_m)$ is the
# output vector, $\bar{x}$ and $\bar{y}$ are the corresponding means, and
# $\hat{\vect{y}} = (\hat{y}_1,\hat{y}_2,\dots,\hat{y}_m)$ is the vector of predicted values.
#
# Under the usual assumption of independent errors of constant variance, the standard errors of the
# two coefficients follow from the residual variance
# $s^2 = \text{SS}_{\text{res}}/(m-2)$:
#
# $$
# \begin{align}
# \text{SE}(b_1) &= \sqrt{\frac{s^2}{\sum_{i=1}^{m}(x_i-\bar{x})^2}}
# \\
# \text{SE}(b_0) &= \sqrt{s^2\left[\frac{1}{m} + \frac{\bar{x}^2}{\sum_{i=1}^{m}(x_i-\bar{x})^2}\right]}
# \end{align}
# $$
#
# The divisor $m-2$ appears because two parameters have already been estimated from the same data.

# %% [markdown]
# ### TASK A1. Implementing the regression class
#
# Complete the three methods of the class below. Use vectorised NumPy operations only, without an
# explicit Python loop over the samples, and without importing `scikit-learn`.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
class LinearRegression:
    """Simple linear regression by ordinary least squares."""

    def fit(self, X, y):
        """Estimate b0 and b1 from one-dimensional arrays X and y.

        Stores the results as self.b0 and self.b1 and returns self.
        """
        m = X.shape[0]

        # TODO 
        # 1. compute the means of X and y
        xmean = np.mean(X)
        ymean = np.mean(y)
        # 2. compute the mean-centred vectors
        xc = X-xmean
        yc = y-ymean
        # 3. obtain b1 from the ratio of the two inner products given in the theory section
        b1 = np.sum(xc*yc)/np.sum(xc**2)
        # 4. obtain b0 from b1 and the two means
        b0 =  ymean- b1*xmean
        # 5. store them as self.b0 and self.b1
        self.b1 = b1
        self.b0 = b0
        # 6. print the pair in the format
        print(f"(b0, b1) = ({self.b0:.3f}, {self.b1:.3f})")
        return self

        ##raise NotImplementedError("Task A1: complete fit(), then delete this line")

    def predict(self, X):
        """Return the predicted response for the array X."""

        # TODO (1 mark)
        y_pred = self.b0 + self.b1*X
        return y_pred
       ## raise NotImplementedError("Task A1: complete predict(), then delete this line")

    def evaluate(self, X, y):
        """Print and return the RMSE and the R^2 score as a tuple."""

        y_pred = self.predict(X)
        rmse = np.sqrt(np.mean((y-y_pred)**2))
        ss_tot = np.sum((y-np.mean(y))**2)
        ss_res = np.sum((y-y_pred)**2)
        r2 = 1 - (ss_res/ss_tot)

        # TODO 
        # compute rmse, ss_tot, ss_res and r2 using the formulae above

        # then print them as
        print("Root mean squared error:", round(rmse, 3))
        print("R^2 value:", round(r2, 3))
        return (rmse, r2)

        ##raise NotImplementedError("Task A1: complete evaluate(), then delete this line")

# %% [markdown]
# ### TASK A2. Plotting the fit
#
# Complete the plotting helper. The scatter of the observed data and the fitted straight line must
# appear on the same axes.

# %% [markdown]
# def regression_plot(X, y, model, title=""):
#     """Scatter plot of the data with the fitted regression line drawn over it."""
#     plt.figure(figsize=(10, 6))
#     plt.title(title)
#
#     # TODO
#     # 1. label the x axis as "Head size (cm^3)" and the y axis as "Brain weight (grams)"
#     # 2. build a two-element array x_line spanning slightly beyond the data range,
#     #    shaped as a column so that both implementations of predict() accept it
#     # 3. evaluate the model on x_line to obtain y_line
#     # 4. draw the observed points with plt.scatter and the fitted line with plt.plot
#     # 5. add a legend and show the figure
#
#     raise NotImplementedError("Task A2: complete regression_plot(), then delete this line")

# %%
def regression_plot(X, y, model, title=""):
    plt.figure(figsize=(10, 6)) 
    plt.title(title)
    x = X
    #1 
    plt.xlabel("Head size (cm^3)")
    plt.ylabel("Brain weight (grams)")
    #2
    xl=np.array([x.min()-10,x.max()+10]).reshape(-1, 1)
    #3
    yl = model.predict(xl)
    #3]4
    plt.scatter(x,y,color = 'g',label = 'observed data')
    plt.plot(xl,yl,color = 'r' ,label = 'fitted line')
    #5
    plt.legend()
    plt.show()

# %% [markdown]
# ### TASK A3. Fitting the head and brain dataset
#
# The dataset relates the head size of an adult to the mass of the brain. Load it, extract the two
# columns of interest, fit the model, plot the result, and evaluate the fit.

# %%
# TODO : read datasets/headbrain.csv into a DataFrame named data,
# then print its shape and display the first five rows
data = pd.read_csv("datasets/headbrain.csv")
print(data.shape)
data.head()
# Out:
# (237, 4)
#    Gender  Age Range  Head Size(cm^3)  Brain Weight(grams)
# 0       1          1             4512                 1530
# 1       1          1             3738                 1297
# 2       1          1             4261                 1335
# 3       1          1             3777                 1282
# 4       1          1             4177                 1590

# %%
# TODO : extract the predictor and the response as one-dimensional NumPy arrays
X = data["Head Size(cm^3)"].to_numpy()  # column "Head Size(cm^3)"
y = data["Brain Weight(grams)"].to_numpy() # column "Brain Weight(grams)"
print(X.shape)
print(y.shape)
# Out:
# (237,)
# (237,)

# %%
# TODO : create the model, fit it, plot the fit, and evaluate it
model = LinearRegression()
model.fit(X,y)
regression_plot(X,y,model, title="Head Size vs Brain Weight")
model.evaluate(X,y)
# Out:
# (b0, b1) = (325.573, 0.263)
# Root mean squared error: 72.121
# R^2 value: 0.639
# (72.1206213783709, 0.639311719957)

# %% [markdown]
# ### TASK A4. Comparison with `scikit-learn`
#
# Repeat the fit with the library estimator and confirm that the two implementations agree.
#
# Note that `scikit-learn` expects a two-dimensional array of predictors, so the input has to be
# reshaped from `(m,)` to `(m, 1)`.

# %%
from sklearn.linear_model import LinearRegression as SkLinearRegression
from sklearn.metrics import mean_squared_error

X1 = X.reshape(-1, 1)

# %%
# TODO 
# 1. fit SkLinearRegression on X1 and y
# 2. reuse regression_plot to display the fit
# 3. print the intercept and the coefficient, the RMSE, and the R^2 score
# 4. print the absolute difference between your own b0, b1 and the library values
#1
sk_model =SkLinearRegression()
sk_model.fit(X1,y)
#2
regression_plot(X,y,sk_model,title = "scikit-learn Linear Regression")
#3
y_pred = sk_model.predict(X1)
rmse = np.sqrt(mean_squared_error(y,y_pred))
r2 = sk_model.score(X1,y)
print("Intercept (b0):", sk_model.intercept_)
print("Coefficient (b1):", sk_model.coef_[0])
print("Root mean squared error:", round(rmse, 3))
print("R^2 value:", round(r2, 3))

#4
print("Difference in b0:" , abs(model.b0-sk_model.intercept_))
print("Difference in b1:" , abs(model.b1-sk_model.coef_[0]))
# Out:
# Intercept (b0): 325.5734210494428
# Coefficient (b1): 0.2634293394893993
# Root mean squared error: 72.121
# R^2 value: 0.639
# Difference in b0: 0.0
# Difference in b1: 0.0

# %% [markdown]
# ### TASK A5. Error estimation
#
# A coefficient reported without an uncertainty is of limited scientific value. In this task the
# uncertainty is estimated in two independent ways, first from the analytical expressions given in
# the theory section and then by resampling.
#
# The 95 per cent confidence interval of a coefficient is approximated as
# $b \pm t_{0.975,\,m-2}\,\text{SE}(b)$, where the critical value is close to 1.96 for a sample of
# this size.

# %%
def coefficient_standard_errors(X, y, model):
    # Return (se_b0, se_b1) for a fitted simple linear regression model.

    # TODO 
    # 1. obtain the residuals y - model.predict(X)
    # 2. compute the residual variance s^2 with the correct number of degrees of freedom
    # 3. compute the two standard errors from the expressions in the theory section
    
    #1
    residuals  = y - model.predict(X)
    #2
    m = len(X)
    s2 = np.sum(residuals**2)/(m-2)
    #3
    xmean = np.mean(X)
    sxx = np.sum((X-xmean)**2)
    sb1 = np.sqrt(s2/sxx)
    sb0 = np.sqrt(s2*(1/m+(xmean**2)/sxx))
    return(sb0,sb1)


    raise NotImplementedError("Task A5: complete coefficient_standard_errors(), then delete this line")


# TODO: report b0 and b1 together with their standard errors and their 95 per cent
# confidence intervals, in the form  b1 = 0.263 +/- 0.010

sb0,sb1 = coefficient_standard_errors(X, y, model)
t = 1.96
print(f"b0 = {model.b0:.3f} +/- {sb0:.3f}")
print(f"95% CI: ({model.b0 - t *sb0:.3f},{model.b0+t*sb0:.3f})")
print(f"b1 = {model.b1:.3f} +/- {sb1:.3f}")
print(f"95% CI: ({model.b1 - t * sb1:.3f},{model.b1+t*sb1:.3f})")
# Out:
# b0 = 325.573 +/- 47.141
# 95% CI: (233.177,417.969)
# b1 = 0.263 +/- 0.013
# 95% CI: (0.238,0.289)

# %%
def bootstrap_slope(X, y, n_resamples=1000, seed=0):
    # Return an array of slope estimates from n_resamples bootstrap replicates.
    rng = np.random.default_rng(seed)

    # TODO 
    # 1. draw an index array of size m with replacement using rng.integers
    # 2. fit the model to the resampled data and store the slope
    # 3. repeat n_resamples times and return the collected slopes
    #1
    m = len(X)
    s = []
    for i in range( n_resamples):
        idx = rng.integers(0,m,size=m)
        #2
        xb = X[idx]
        yb = y[idx]
        temp =  LinearRegression()
        temp.fit(xb,yb)
        s.append(temp.b1)
     #3
    return np.array(s)
    
    raise NotImplementedError("Task A5: complete bootstrap_slope(), then delete this line")


# TODO: plot a histogram of the bootstrap slopes, print their standard deviation,
# and compare it with the analytical SE(b1) obtained above. Comment on the agreement.
s =  bootstrap_slope(X, y)
plt.figure(figsize=(8, 5))
plt.hist(s,bins=30, edgecolor="black")
plt.xlabel("Slope estimates")
plt.ylabel("Frequency")
plt.title("Bootstrap distribution of the slope")
plt.show()
bootstrap_se = np.std(s,ddof=1)

print("Bootstrap SE(b1):", round(bootstrap_se, 5))
print("Analytical SE(b1):", round(sb1, 5))
# Out:
# (b0, b1) = (378.726, 0.248)
# (b0, b1) = (331.318, 0.263)
# (b0, b1) = (280.077, 0.276)
# (b0, b1) = (271.900, 0.277)
# (b0, b1) = (337.163, 0.260)
# (b0, b1) = (302.642, 0.270)
# (b0, b1) = (279.532, 0.275)
# (b0, b1) = (292.682, 0.273)
# (b0, b1) = (379.985, 0.250)
# (b0, b1) = (279.597, 0.277)
# (b0, b1) = (397.224, 0.242)
# (b0, b1) = (366.474, 0.251)
# (b0, b1) = (295.008, 0.273)
# (b0, b1) = (380.039, 0.248)
# (b0, b1) = (341.499, 0.258)
# (b0, b1) = (415.911, 0.242)
# (b0, b1) = (341.483, 0.259)
# (b0, b1) = (340.068, 0.261)
# (b0, b1) = (315.099, 0.267)
# (b0, b1) = (368.813, 0.251)
# (b0, b1) = (342.090, 0.259)
# (b0, b1) = (259.536, 0.280)
# (b0, b1) = (355.545, 0.257)
# (b0, b1) = (324.950, 0.263)
# (b0, b1) = (315.215, 0.267)
# (b0, b1) = (246.109, 0.284)
# (b0, b1) = (285.787, 0.276)
# (b0, b1) = (361.210, 0.254)
# (b0, b1) = (357.297, 0.254)
# (b0, b1) = (370.527, 0.251)
# (b0, b1) = (291.618, 0.273)
# (b0, b1) = (318.630, 0.264)
# (b0, b1) = (336.631, 0.261)
# (b0, b1) = (399.243, 0.242)
# (b0, b1) = (394.947, 0.245)
# (b0, b1) = (325.733, 0.264)
# (b0, b1) = (297.053, 0.271)
# (b0, b1) = (316.710, 0.267)
# (b0, b1) = (328.808, 0.264)
# (b0, b1) = (289.540, 0.273)
# (b0, b1) = (252.386, 0.286)
# (b0, b1) = (297.543, 0.272)
# (b0, b1) = (389.055, 0.245)
# (b0, b1) = (357.325, 0.255)
# (b0, b1) = (241.223, 0.286)
# (b0, b1) = (335.232, 0.262)
# (b0, b1) = (294.489, 0.272)
# (b0, b1) = (302.615, 0.271)
# (b0, b1) = (355.034, 0.255)
# (b0, b1) = (351.619, 0.256)
# (b0, b1) = (248.827, 0.286)
# (b0, b1) = (335.910, 0.262)
# (b0, b1) = (399.916, 0.242)
# (b0, b1) = (360.724, 0.253)
# (b0, b1) = (374.412, 0.249)
# (b0, b1) = (222.438, 0.292)
# (b0, b1) = (325.463, 0.264)
# (b0, b1) = (268.005, 0.281)
# (b0, b1) = (272.038, 0.278)
# (b0, b1) = (302.047, 0.269)
# (b0, b1) = (339.127, 0.260)
# (b0, b1) = (409.372, 0.240)
# (b0, b1) = (465.529, 0.225)
# (b0, b1) = (355.433, 0.254)
# (b0, b1) = (425.637, 0.239)
# (b0, b1) = (307.801, 0.270)
# (b0, b1) = (298.707, 0.269)
# (b0, b1) = (309.260, 0.270)
# (b0, b1) = (340.402, 0.260)
# (b0, b1) = (314.238, 0.269)
# (b0, b1) = (297.256, 0.270)
# (b0, b1) = (333.419, 0.261)
# (b0, b1) = (305.731, 0.270)
# (b0, b1) = (312.815, 0.266)
# (b0, b1) = (368.355, 0.251)
# (b0, b1) = (333.642, 0.260)
# (b0, b1) = (356.573, 0.254)
# (b0, b1) = (336.642, 0.261)
# (b0, b1) = (284.875, 0.275)
# (b0, b1) = (348.716, 0.258)
# (b0, b1) = (399.202, 0.242)
# (b0, b1) = (329.493, 0.262)
# (b0, b1) = (347.098, 0.261)
# (b0, b1) = (368.843, 0.251)
# (b0, b1) = (305.094, 0.268)
# (b0, b1) = (300.792, 0.271)
# (b0, b1) = (323.455, 0.264)
# (b0, b1) = (224.521, 0.290)
# (b0, b1) = (256.693, 0.284)
# (b0, b1) = (348.633, 0.257)
# (b0, b1) = (253.573, 0.285)
# (b0, b1) = (299.497, 0.267)
# (b0, b1) = (333.565, 0.262)
# (b0, b1) = (339.172, 0.260)
# (b0, b1) = (283.223, 0.276)
# (b0, b1) = (344.570, 0.257)
# (b0, b1) = (345.761, 0.258)
# (b0, b1) = (251.122, 0.285)
# (b0, b1) = (316.380, 0.265)
# (b0, b1) = (301.078, 0.270)
# (b0, b1) = (307.212, 0.270)
# (b0, b1) = (235.063, 0.289)
# (b0, b1) = (300.380, 0.271)
# (b0, b1) = (267.859, 0.282)
# (b0, b1) = (293.193, 0.273)
# (b0, b1) = (351.578, 0.257)
# (b0, b1) = (321.409, 0.264)
# (b0, b1) = (333.002, 0.259)
# (b0, b1) = (365.011, 0.253)
# (b0, b1) = (367.302, 0.253)
# (b0, b1) = (295.900, 0.272)
# (b0, b1) = (327.995, 0.261)
# (b0, b1) = (402.128, 0.243)
# (b0, b1) = (368.093, 0.250)
# (b0, b1) = (351.197, 0.258)
# (b0, b1) = (236.765, 0.287)
# (b0, b1) = (261.372, 0.282)
# (b0, b1) = (280.031, 0.277)
# (b0, b1) = (371.047, 0.250)
# (b0, b1) = (321.039, 0.265)
# (b0, b1) = (332.126, 0.262)
# (b0, b1) = (340.420, 0.258)
# (b0, b1) = (318.758, 0.267)
# (b0, b1) = (311.449, 0.269)
# (b0, b1) = (320.574, 0.264)
# (b0, b1) = (375.272, 0.248)
# (b0, b1) = (274.990, 0.277)
# (b0, b1) = (323.257, 0.264)
# (b0, b1) = (389.113, 0.244)
# (b0, b1) = (310.069, 0.267)
# (b0, b1) = (354.823, 0.257)
# (b0, b1) = (388.255, 0.245)
# (b0, b1) = (311.597, 0.268)
# (b0, b1) = (270.120, 0.280)
# (b0, b1) = (305.077, 0.271)
# (b0, b1) = (344.323, 0.261)
# (b0, b1) = (418.881, 0.238)
# (b0, b1) = (350.516, 0.256)
# (b0, b1) = (328.595, 0.263)
# (b0, b1) = (357.489, 0.255)
# (b0, b1) = (347.475, 0.258)
# (b0, b1) = (287.225, 0.275)
# (b0, b1) = (363.700, 0.252)
# (b0, b1) = (473.855, 0.223)
# (b0, b1) = (365.240, 0.249)
# (b0, b1) = (316.961, 0.265)
# (b0, b1) = (355.429, 0.254)
# (b0, b1) = (277.216, 0.278)
# (b0, b1) = (341.716, 0.260)
# (b0, b1) = (296.148, 0.272)
# (b0, b1) = (344.782, 0.259)
# (b0, b1) = (304.154, 0.268)
# (b0, b1) = (386.312, 0.247)
# (b0, b1) = (310.846, 0.267)
# (b0, b1) = (275.102, 0.278)
# (b0, b1) = (264.137, 0.279)
# (b0, b1) = (424.343, 0.236)
# (b0, b1) = (333.461, 0.260)
# (b0, b1) = (379.537, 0.248)
# (b0, b1) = (323.394, 0.266)
# (b0, b1) = (283.253, 0.275)
# (b0, b1) = (283.149, 0.276)
# (b0, b1) = (354.330, 0.253)
# (b0, b1) = (338.049, 0.258)
# (b0, b1) = (297.060, 0.269)
# (b0, b1) = (383.802, 0.249)
# (b0, b1) = (319.747, 0.267)
# (b0, b1) = (356.208, 0.255)
# (b0, b1) = (211.318, 0.295)
# (b0, b1) = (269.960, 0.278)
# (b0, b1) = (355.910, 0.254)
# (b0, b1) = (309.280, 0.267)
# (b0, b1) = (357.635, 0.255)
# (b0, b1) = (358.449, 0.254)
# (b0, b1) = (352.888, 0.256)
# (b0, b1) = (259.587, 0.282)
# (b0, b1) = (367.799, 0.251)
# (b0, b1) = (389.625, 0.248)
# (b0, b1) = (417.072, 0.238)
# (b0, b1) = (360.008, 0.253)
# (b0, b1) = (359.982, 0.254)
# (b0, b1) = (311.413, 0.266)
# (b0, b1) = (296.392, 0.272)
# (b0, b1) = (384.379, 0.246)
# (b0, b1) = (407.826, 0.241)
# (b0, b1) = (376.964, 0.250)
# (b0, b1) = (281.733, 0.277)
# (b0, b1) = (302.640, 0.272)
# (b0, b1) = (248.224, 0.283)
# (b0, b1) = (317.112, 0.268)
# (b0, b1) = (266.196, 0.281)
# (b0, b1) = (303.324, 0.272)
# (b0, b1) = (331.151, 0.260)
# (b0, b1) = (445.786, 0.233)
# (b0, b1) = (347.871, 0.258)
# (b0, b1) = (325.398, 0.265)
# (b0, b1) = (259.728, 0.282)
# (b0, b1) = (271.708, 0.279)
# (b0, b1) = (270.110, 0.280)
# (b0, b1) = (284.313, 0.275)
# (b0, b1) = (360.535, 0.254)
# (b0, b1) = (367.886, 0.252)
# (b0, b1) = (300.704, 0.271)
# (b0, b1) = (315.465, 0.266)
# (b0, b1) = (324.260, 0.264)
# (b0, b1) = (349.665, 0.259)
# (b0, b1) = (302.091, 0.272)
# (b0, b1) = (341.372, 0.261)
# (b0, b1) = (305.674, 0.271)
# (b0, b1) = (325.249, 0.265)
# (b0, b1) = (379.372, 0.249)
# (b0, b1) = (332.349, 0.263)
# (b0, b1) = (381.201, 0.248)
# (b0, b1) = (252.343, 0.285)
# (b0, b1) = (330.880, 0.259)
# (b0, b1) = (292.752, 0.273)
# (b0, b1) = (287.271, 0.273)
# (b0, b1) = (361.949, 0.255)
# (b0, b1) = (282.613, 0.275)
# (b0, b1) = (382.015, 0.247)
# (b0, b1) = (324.953, 0.262)
# (b0, b1) = (334.729, 0.261)
# (b0, b1) = (284.527, 0.276)
# (b0, b1) = (335.246, 0.264)
# (b0, b1) = (399.948, 0.243)
# (b0, b1) = (307.175, 0.271)
# (b0, b1) = (290.616, 0.273)
# (b0, b1) = (326.470, 0.262)
# (b0, b1) = (356.875, 0.256)
# (b0, b1) = (430.706, 0.235)
# (b0, b1) = (352.382, 0.257)
# (b0, b1) = (323.322, 0.264)
# (b0, b1) = (298.242, 0.270)
# (b0, b1) = (280.841, 0.275)
# (b0, b1) = (269.971, 0.278)
# (b0, b1) = (354.684, 0.256)
# (b0, b1) = (400.242, 0.244)
# (b0, b1) = (363.864, 0.253)
# (b0, b1) = (365.134, 0.252)
# (b0, b1) = (330.974, 0.263)
# (b0, b1) = (388.507, 0.249)
# (b0, b1) = (225.835, 0.292)
# (b0, b1) = (257.521, 0.282)
# (b0, b1) = (283.262, 0.277)
# (b0, b1) = (391.718, 0.246)
# (b0, b1) = (303.437, 0.269)
# (b0, b1) = (333.790, 0.262)
# (b0, b1) = (339.234, 0.258)
# (b0, b1) = (301.119, 0.271)
# (b0, b1) = (269.661, 0.280)
# (b0, b1) = (366.985, 0.251)
# (b0, b1) = (273.852, 0.275)
# (b0, b1) = (313.089, 0.268)
# (b0, b1) = (401.557, 0.240)
# (b0, b1) = (371.694, 0.251)
# (b0, b1) = (325.853, 0.264)
# (b0, b1) = (355.509, 0.256)
# (b0, b1) = (349.147, 0.255)
# (b0, b1) = (296.895, 0.273)
# (b0, b1) = (309.247, 0.267)
# (b0, b1) = (360.221, 0.250)
# (b0, b1) = (270.463, 0.277)
# (b0, b1) = (301.303, 0.270)
# (b0, b1) = (398.063, 0.245)
# (b0, b1) = (375.389, 0.249)
# (b0, b1) = (331.436, 0.261)
# (b0, b1) = (384.906, 0.247)
# (b0, b1) = (319.391, 0.266)
# (b0, b1) = (376.935, 0.249)
# (b0, b1) = (305.246, 0.270)
# (b0, b1) = (400.900, 0.245)
# (b0, b1) = (320.195, 0.264)
# (b0, b1) = (298.474, 0.272)
# (b0, b1) = (348.277, 0.257)
# (b0, b1) = (275.377, 0.278)
# (b0, b1) = (384.744, 0.247)
# (b0, b1) = (337.729, 0.260)
# (b0, b1) = (310.353, 0.268)
# (b0, b1) = (347.343, 0.257)
# (b0, b1) = (358.470, 0.254)
# (b0, b1) = (332.320, 0.261)
# (b0, b1) = (350.938, 0.256)
# (b0, b1) = (187.038, 0.300)
# (b0, b1) = (366.738, 0.251)
# (b0, b1) = (337.030, 0.262)
# (b0, b1) = (392.527, 0.246)
# (b0, b1) = (380.776, 0.249)
# (b0, b1) = (257.285, 0.283)
# (b0, b1) = (386.316, 0.246)
# (b0, b1) = (315.084, 0.266)
# (b0, b1) = (365.257, 0.252)
# (b0, b1) = (332.460, 0.262)
# (b0, b1) = (341.290, 0.259)
# (b0, b1) = (276.898, 0.275)
# (b0, b1) = (279.757, 0.274)
# (b0, b1) = (396.738, 0.243)
# (b0, b1) = (295.318, 0.271)
# (b0, b1) = (307.773, 0.269)
# (b0, b1) = (293.839, 0.273)
# (b0, b1) = (343.131, 0.258)
# (b0, b1) = (236.880, 0.288)
# (b0, b1) = (290.118, 0.273)
# (b0, b1) = (390.699, 0.245)
# (b0, b1) = (279.813, 0.278)
# (b0, b1) = (296.249, 0.272)
# (b0, b1) = (342.249, 0.258)
# (b0, b1) = (359.399, 0.251)
# (b0, b1) = (304.613, 0.269)
# (b0, b1) = (304.746, 0.272)
# (b0, b1) = (395.551, 0.243)
# (b0, b1) = (397.535, 0.244)
# (b0, b1) = (325.623, 0.260)
# (b0, b1) = (376.788, 0.250)
# (b0, b1) = (259.471, 0.282)
# (b0, b1) = (349.159, 0.258)
# (b0, b1) = (351.992, 0.255)
# (b0, b1) = (285.302, 0.273)
# (b0, b1) = (358.715, 0.254)
# (b0, b1) = (379.702, 0.248)
# (b0, b1) = (295.237, 0.272)
# (b0, b1) = (369.619, 0.253)
# (b0, b1) = (307.934, 0.268)
# (b0, b1) = (306.599, 0.269)
# (b0, b1) = (312.741, 0.267)
# (b0, b1) = (459.735, 0.224)
# (b0, b1) = (270.677, 0.276)
# (b0, b1) = (411.733, 0.240)
# (b0, b1) = (293.200, 0.273)
# (b0, b1) = (312.949, 0.268)
# (b0, b1) = (297.561, 0.271)
# (b0, b1) = (335.369, 0.260)
# (b0, b1) = (405.013, 0.240)
# (b0, b1) = (305.480, 0.270)
# (b0, b1) = (228.848, 0.291)
# (b0, b1) = (407.722, 0.242)
# (b0, b1) = (333.530, 0.264)
# (b0, b1) = (344.783, 0.260)
# (b0, b1) = (331.824, 0.262)
# (b0, b1) = (401.285, 0.243)
# (b0, b1) = (304.924, 0.268)
# (b0, b1) = (259.299, 0.282)
# (b0, b1) = (266.630, 0.279)
# (b0, b1) = (290.105, 0.273)
# (b0, b1) = (362.870, 0.253)
# (b0, b1) = (303.886, 0.269)
# (b0, b1) = (299.730, 0.270)
# (b0, b1) = (307.443, 0.268)
# (b0, b1) = (383.213, 0.246)
# (b0, b1) = (317.230, 0.265)
# (b0, b1) = (369.619, 0.251)
# (b0, b1) = (281.983, 0.277)
# (b0, b1) = (341.386, 0.259)
# (b0, b1) = (296.932, 0.271)
# (b0, b1) = (313.135, 0.269)
# (b0, b1) = (274.960, 0.276)
# (b0, b1) = (317.010, 0.268)
# (b0, b1) = (300.866, 0.272)
# (b0, b1) = (306.655, 0.269)
# (b0, b1) = (384.852, 0.251)
# (b0, b1) = (283.205, 0.275)
# (b0, b1) = (368.952, 0.252)
# (b0, b1) = (377.500, 0.247)
# (b0, b1) = (324.109, 0.263)
# (b0, b1) = (296.692, 0.273)
# (b0, b1) = (312.102, 0.267)
# (b0, b1) = (272.326, 0.279)
# (b0, b1) = (317.797, 0.264)
# (b0, b1) = (283.752, 0.277)
# (b0, b1) = (304.676, 0.268)
# (b0, b1) = (343.882, 0.261)
# (b0, b1) = (317.939, 0.264)
# (b0, b1) = (350.364, 0.257)
# (b0, b1) = (342.585, 0.258)
# (b0, b1) = (401.838, 0.243)
# (b0, b1) = (385.726, 0.247)
# (b0, b1) = (291.955, 0.277)
# (b0, b1) = (288.646, 0.273)
# (b0, b1) = (378.926, 0.250)
# (b0, b1) = (447.342, 0.229)
# (b0, b1) = (351.181, 0.255)
# (b0, b1) = (315.849, 0.266)
# (b0, b1) = (232.236, 0.292)
# (b0, b1) = (385.726, 0.248)
# (b0, b1) = (304.083, 0.269)
# (b0, b1) = (289.726, 0.274)
# (b0, b1) = (311.094, 0.269)
# (b0, b1) = (307.942, 0.270)
# (b0, b1) = (279.940, 0.274)
# (b0, b1) = (343.403, 0.258)
# (b0, b1) = (316.187, 0.267)
# (b0, b1) = (329.512, 0.262)
# (b0, b1) = (343.234, 0.260)
# (b0, b1) = (278.991, 0.275)
# (b0, b1) = (343.334, 0.257)
# (b0, b1) = (364.119, 0.254)
# (b0, b1) = (386.235, 0.245)
# (b0, b1) = (246.287, 0.287)
# (b0, b1) = (310.361, 0.271)
# (b0, b1) = (324.711, 0.264)
# (b0, b1) = (368.316, 0.254)
# (b0, b1) = (456.907, 0.227)
# (b0, b1) = (307.404, 0.270)
# (b0, b1) = (373.697, 0.251)
# (b0, b1) = (351.487, 0.256)
# (b0, b1) = (296.299, 0.270)
# (b0, b1) = (279.426, 0.277)
# (b0, b1) = (323.766, 0.264)
# (b0, b1) = (253.875, 0.283)
# (b0, b1) = (308.899, 0.269)
# (b0, b1) = (340.765, 0.255)
# (b0, b1) = (239.192, 0.287)
# (b0, b1) = (399.734, 0.241)
# (b0, b1) = (337.245, 0.261)
# (b0, b1) = (304.862, 0.270)
# (b0, b1) = (291.625, 0.273)
# (b0, b1) = (340.833, 0.262)
# (b0, b1) = (325.085, 0.264)
# (b0, b1) = (312.637, 0.269)
# (b0, b1) = (280.569, 0.277)
# (b0, b1) = (331.999, 0.263)
# (b0, b1) = (324.810, 0.264)
# (b0, b1) = (334.944, 0.261)
# (b0, b1) = (448.218, 0.230)
# (b0, b1) = (268.843, 0.279)
# (b0, b1) = (334.941, 0.258)
# (b0, b1) = (294.793, 0.270)
# (b0, b1) = (266.895, 0.281)
# (b0, b1) = (367.683, 0.251)
# (b0, b1) = (291.016, 0.275)
# (b0, b1) = (355.933, 0.254)
# (b0, b1) = (261.053, 0.283)
# (b0, b1) = (376.401, 0.249)
# (b0, b1) = (270.122, 0.280)
# (b0, b1) = (346.973, 0.258)
# (b0, b1) = (254.416, 0.283)
# (b0, b1) = (360.728, 0.256)
# (b0, b1) = (296.863, 0.271)
# (b0, b1) = (281.042, 0.277)
# (b0, b1) = (306.885, 0.267)
# (b0, b1) = (291.177, 0.273)
# (b0, b1) = (378.834, 0.249)
# (b0, b1) = (236.443, 0.290)
# (b0, b1) = (301.468, 0.271)
# (b0, b1) = (370.719, 0.251)
# (b0, b1) = (324.890, 0.264)
# (b0, b1) = (353.169, 0.254)
# (b0, b1) = (341.570, 0.259)
# (b0, b1) = (311.741, 0.265)
# (b0, b1) = (417.974, 0.239)
# (b0, b1) = (350.411, 0.255)
# (b0, b1) = (305.605, 0.269)
# (b0, b1) = (323.511, 0.264)
# (b0, b1) = (401.909, 0.242)
# (b0, b1) = (362.647, 0.249)
# (b0, b1) = (308.464, 0.271)
# (b0, b1) = (350.922, 0.258)
# (b0, b1) = (332.599, 0.264)
# (b0, b1) = (378.214, 0.250)
# (b0, b1) = (329.513, 0.264)
# (b0, b1) = (252.341, 0.284)
# (b0, b1) = (390.633, 0.245)
# (b0, b1) = (371.073, 0.250)
# (b0, b1) = (317.043, 0.266)
# (b0, b1) = (297.918, 0.271)
# (b0, b1) = (289.402, 0.274)
# (b0, b1) = (296.733, 0.274)
# (b0, b1) = (271.155, 0.278)
# (b0, b1) = (294.749, 0.270)
# (b0, b1) = (262.531, 0.281)
# (b0, b1) = (356.640, 0.255)
# (b0, b1) = (306.347, 0.267)
# (b0, b1) = (349.826, 0.256)
# (b0, b1) = (340.393, 0.260)
# (b0, b1) = (283.805, 0.275)
# (b0, b1) = (292.995, 0.275)
# (b0, b1) = (338.926, 0.260)
# (b0, b1) = (284.099, 0.274)
# (b0, b1) = (386.325, 0.246)
# (b0, b1) = (423.693, 0.236)
# (b0, b1) = (349.916, 0.256)
# (b0, b1) = (278.006, 0.277)
# (b0, b1) = (423.620, 0.235)
# (b0, b1) = (299.624, 0.269)
# (b0, b1) = (372.681, 0.249)
# (b0, b1) = (344.425, 0.259)
# (b0, b1) = (397.756, 0.242)
# (b0, b1) = (283.129, 0.276)
# (b0, b1) = (362.700, 0.252)
# (b0, b1) = (390.536, 0.246)
# (b0, b1) = (363.688, 0.253)
# (b0, b1) = (293.686, 0.271)
# (b0, b1) = (259.661, 0.282)
# (b0, b1) = (340.817, 0.259)
# (b0, b1) = (379.647, 0.248)
# (b0, b1) = (323.240, 0.266)
# (b0, b1) = (304.827, 0.269)
# (b0, b1) = (307.574, 0.269)
# (b0, b1) = (345.041, 0.255)
# (b0, b1) = (293.386, 0.270)
# (b0, b1) = (325.718, 0.263)
# (b0, b1) = (284.499, 0.274)
# (b0, b1) = (276.416, 0.276)
# (b0, b1) = (232.218, 0.289)
# (b0, b1) = (342.680, 0.259)
# (b0, b1) = (337.763, 0.259)
# (b0, b1) = (261.052, 0.283)
# (b0, b1) = (322.240, 0.265)
# (b0, b1) = (385.934, 0.247)
# (b0, b1) = (304.895, 0.268)
# (b0, b1) = (325.638, 0.263)
# (b0, b1) = (287.441, 0.275)
# (b0, b1) = (408.619, 0.243)
# (b0, b1) = (442.898, 0.232)
# (b0, b1) = (242.279, 0.287)
# (b0, b1) = (439.893, 0.233)
# (b0, b1) = (338.910, 0.260)
# (b0, b1) = (297.699, 0.269)
# (b0, b1) = (396.294, 0.244)
# (b0, b1) = (410.441, 0.242)
# (b0, b1) = (392.353, 0.246)
# (b0, b1) = (251.132, 0.284)
# (b0, b1) = (231.661, 0.290)
# (b0, b1) = (325.931, 0.263)
# (b0, b1) = (392.878, 0.244)
# (b0, b1) = (312.915, 0.266)
# (b0, b1) = (247.902, 0.285)
# (b0, b1) = (337.354, 0.260)
# (b0, b1) = (242.842, 0.286)
# (b0, b1) = (260.106, 0.282)
# (b0, b1) = (353.914, 0.254)
# (b0, b1) = (340.029, 0.260)
# (b0, b1) = (309.203, 0.267)
# (b0, b1) = (346.149, 0.257)
# (b0, b1) = (306.184, 0.270)
# (b0, b1) = (286.312, 0.276)
# (b0, b1) = (344.216, 0.257)
# (b0, b1) = (258.724, 0.282)
# (b0, b1) = (365.621, 0.251)
# (b0, b1) = (242.726, 0.284)
# (b0, b1) = (284.781, 0.275)
# (b0, b1) = (362.745, 0.253)
# (b0, b1) = (355.645, 0.255)
# (b0, b1) = (361.857, 0.255)
# (b0, b1) = (331.664, 0.261)
# (b0, b1) = (213.853, 0.294)
# (b0, b1) = (277.309, 0.276)
# (b0, b1) = (291.560, 0.272)
# (b0, b1) = (308.236, 0.270)
# (b0, b1) = (347.651, 0.257)
# (b0, b1) = (316.934, 0.263)
# (b0, b1) = (423.213, 0.236)
# (b0, b1) = (358.796, 0.254)
# (b0, b1) = (255.403, 0.285)
# (b0, b1) = (269.310, 0.278)
# (b0, b1) = (357.863, 0.256)
# (b0, b1) = (349.137, 0.256)
# (b0, b1) = (317.470, 0.266)
# (b0, b1) = (363.556, 0.253)
# (b0, b1) = (263.310, 0.281)
# (b0, b1) = (307.319, 0.268)
# (b0, b1) = (274.271, 0.277)
# (b0, b1) = (358.307, 0.256)
# (b0, b1) = (298.427, 0.273)
# (b0, b1) = (335.712, 0.259)
# (b0, b1) = (417.428, 0.236)
# (b0, b1) = (327.273, 0.263)
# (b0, b1) = (326.424, 0.265)
# (b0, b1) = (306.690, 0.269)
# (b0, b1) = (270.781, 0.279)
# (b0, b1) = (291.607, 0.273)
# (b0, b1) = (339.796, 0.259)
# (b0, b1) = (294.332, 0.273)
# (b0, b1) = (397.931, 0.245)
# (b0, b1) = (345.093, 0.260)
# (b0, b1) = (365.182, 0.251)
# (b0, b1) = (355.297, 0.253)
# (b0, b1) = (311.974, 0.265)
# (b0, b1) = (268.482, 0.280)
# (b0, b1) = (288.500, 0.274)
# (b0, b1) = (384.286, 0.246)
# (b0, b1) = (254.434, 0.286)
# (b0, b1) = (242.642, 0.288)
# (b0, b1) = (189.337, 0.301)
# (b0, b1) = (343.964, 0.258)
# (b0, b1) = (333.256, 0.259)
# (b0, b1) = (211.807, 0.294)
# (b0, b1) = (296.476, 0.269)
# (b0, b1) = (337.208, 0.260)
# (b0, b1) = (343.652, 0.260)
# (b0, b1) = (343.739, 0.258)
# (b0, b1) = (380.357, 0.249)
# (b0, b1) = (339.488, 0.259)
# (b0, b1) = (317.468, 0.268)
# (b0, b1) = (305.499, 0.269)
# (b0, b1) = (345.389, 0.256)
# (b0, b1) = (428.826, 0.235)
# (b0, b1) = (254.514, 0.284)
# (b0, b1) = (305.704, 0.270)
# (b0, b1) = (327.636, 0.263)
# (b0, b1) = (348.608, 0.256)
# (b0, b1) = (355.222, 0.254)
# (b0, b1) = (303.248, 0.270)
# (b0, b1) = (367.144, 0.256)
# (b0, b1) = (363.677, 0.253)
# (b0, b1) = (309.322, 0.266)
# (b0, b1) = (349.785, 0.256)
# (b0, b1) = (290.789, 0.273)
# (b0, b1) = (350.224, 0.254)
# (b0, b1) = (334.602, 0.261)
# (b0, b1) = (284.016, 0.274)
# (b0, b1) = (339.576, 0.260)
# (b0, b1) = (265.097, 0.278)
# (b0, b1) = (376.733, 0.249)
# (b0, b1) = (317.520, 0.264)
# (b0, b1) = (365.116, 0.254)
# (b0, b1) = (271.001, 0.280)
# (b0, b1) = (305.233, 0.270)
# (b0, b1) = (382.944, 0.246)
# (b0, b1) = (322.248, 0.263)
# (b0, b1) = (309.219, 0.267)
# (b0, b1) = (348.108, 0.256)
# (b0, b1) = (292.025, 0.272)
# (b0, b1) = (274.376, 0.279)
# (b0, b1) = (354.912, 0.256)
# (b0, b1) = (356.526, 0.254)
# (b0, b1) = (337.421, 0.262)
# (b0, b1) = (305.331, 0.271)
# (b0, b1) = (365.339, 0.252)
# (b0, b1) = (250.440, 0.285)
# (b0, b1) = (311.928, 0.267)
# (b0, b1) = (327.656, 0.263)
# (b0, b1) = (268.956, 0.280)
# (b0, b1) = (312.808, 0.266)
# (b0, b1) = (292.959, 0.273)
# (b0, b1) = (260.322, 0.281)
# (b0, b1) = (285.903, 0.276)
# (b0, b1) = (332.557, 0.260)
# (b0, b1) = (283.785, 0.277)
# (b0, b1) = (268.429, 0.280)
# (b0, b1) = (293.671, 0.272)
# (b0, b1) = (290.130, 0.273)
# (b0, b1) = (311.203, 0.268)
# (b0, b1) = (263.554, 0.277)
# (b0, b1) = (407.801, 0.240)
# (b0, b1) = (330.641, 0.261)
# (b0, b1) = (374.831, 0.249)
# (b0, b1) = (319.044, 0.266)
# (b0, b1) = (386.982, 0.246)
# (b0, b1) = (266.534, 0.278)
# (b0, b1) = (318.624, 0.267)
# (b0, b1) = (401.028, 0.242)
# (b0, b1) = (319.858, 0.266)
# (b0, b1) = (377.017, 0.247)
# (b0, b1) = (404.016, 0.242)
# (b0, b1) = (327.759, 0.263)
# (b0, b1) = (334.593, 0.260)
# (b0, b1) = (386.329, 0.248)
# (b0, b1) = (378.056, 0.248)
# (b0, b1) = (339.662, 0.262)
# (b0, b1) = (285.154, 0.274)
# (b0, b1) = (290.693, 0.273)
# (b0, b1) = (352.393, 0.256)
# (b0, b1) = (268.013, 0.280)
# (b0, b1) = (256.327, 0.282)
# (b0, b1) = (384.961, 0.246)
# (b0, b1) = (306.917, 0.271)
# (b0, b1) = (342.686, 0.260)
# (b0, b1) = (346.904, 0.255)
# (b0, b1) = (377.627, 0.248)
# (b0, b1) = (302.900, 0.268)
# (b0, b1) = (319.880, 0.266)
# (b0, b1) = (289.840, 0.273)
# (b0, b1) = (270.470, 0.277)
# (b0, b1) = (312.420, 0.266)
# (b0, b1) = (295.097, 0.272)
# (b0, b1) = (258.159, 0.283)
# (b0, b1) = (321.252, 0.264)
# (b0, b1) = (318.822, 0.265)
# (b0, b1) = (302.518, 0.272)
# (b0, b1) = (291.546, 0.274)
# (b0, b1) = (346.983, 0.256)
# (b0, b1) = (287.698, 0.273)
# (b0, b1) = (285.915, 0.275)
# (b0, b1) = (400.443, 0.241)
# (b0, b1) = (297.779, 0.273)
# (b0, b1) = (321.745, 0.265)
# (b0, b1) = (364.471, 0.254)
# (b0, b1) = (339.252, 0.261)
# (b0, b1) = (321.681, 0.262)
# (b0, b1) = (280.712, 0.275)
# (b0, b1) = (280.277, 0.277)
# (b0, b1) = (334.371, 0.261)
# (b0, b1) = (276.224, 0.276)
# (b0, b1) = (365.134, 0.249)
# (b0, b1) = (316.533, 0.263)
# (b0, b1) = (306.016, 0.271)
# (b0, b1) = (351.028, 0.256)
# (b0, b1) = (278.683, 0.277)
# (b0, b1) = (341.359, 0.260)
# (b0, b1) = (275.730, 0.275)
# (b0, b1) = (346.632, 0.259)
# (b0, b1) = (312.039, 0.268)
# (b0, b1) = (352.440, 0.257)
# (b0, b1) = (238.101, 0.289)
# (b0, b1) = (332.423, 0.260)
# (b0, b1) = (346.576, 0.257)
# (b0, b1) = (278.357, 0.278)
# (b0, b1) = (301.216, 0.268)
# (b0, b1) = (361.565, 0.256)
# (b0, b1) = (356.648, 0.254)
# (b0, b1) = (364.335, 0.252)
# (b0, b1) = (298.990, 0.270)
# (b0, b1) = (370.046, 0.251)
# (b0, b1) = (332.317, 0.263)
# (b0, b1) = (365.021, 0.251)
# (b0, b1) = (354.776, 0.255)
# (b0, b1) = (322.897, 0.266)
# (b0, b1) = (357.449, 0.254)
# (b0, b1) = (417.605, 0.237)
# (b0, b1) = (380.395, 0.248)
# (b0, b1) = (302.842, 0.269)
# (b0, b1) = (443.520, 0.231)
# (b0, b1) = (373.732, 0.251)
# (b0, b1) = (334.402, 0.260)
# (b0, b1) = (361.851, 0.253)
# (b0, b1) = (340.440, 0.258)
# (b0, b1) = (372.684, 0.251)
# (b0, b1) = (290.770, 0.276)
# (b0, b1) = (331.381, 0.262)
# (b0, b1) = (322.565, 0.263)
# (b0, b1) = (404.788, 0.242)
# (b0, b1) = (319.169, 0.268)
# (b0, b1) = (292.092, 0.271)
# (b0, b1) = (275.869, 0.277)
# (b0, b1) = (327.840, 0.263)
# (b0, b1) = (297.341, 0.272)
# (b0, b1) = (346.646, 0.257)
# (b0, b1) = (306.618, 0.268)
# (b0, b1) = (334.456, 0.260)
# (b0, b1) = (445.593, 0.228)
# (b0, b1) = (253.764, 0.284)
# (b0, b1) = (342.708, 0.257)
# (b0, b1) = (287.023, 0.275)
# (b0, b1) = (379.554, 0.248)
# (b0, b1) = (287.837, 0.274)
# (b0, b1) = (344.611, 0.260)
# (b0, b1) = (297.864, 0.270)
# (b0, b1) = (264.106, 0.281)
# (b0, b1) = (368.542, 0.251)
# (b0, b1) = (378.788, 0.249)
# (b0, b1) = (297.808, 0.270)
# (b0, b1) = (325.538, 0.263)
# (b0, b1) = (299.304, 0.270)
# (b0, b1) = (314.173, 0.265)
# (b0, b1) = (338.288, 0.262)
# (b0, b1) = (293.662, 0.270)
# (b0, b1) = (360.165, 0.254)
# (b0, b1) = (337.954, 0.260)
# (b0, b1) = (350.721, 0.257)
# (b0, b1) = (350.790, 0.256)
# (b0, b1) = (286.425, 0.274)
# (b0, b1) = (279.679, 0.278)
# (b0, b1) = (302.955, 0.270)
# (b0, b1) = (313.319, 0.266)
# (b0, b1) = (330.714, 0.260)
# (b0, b1) = (208.822, 0.298)
# (b0, b1) = (436.693, 0.232)
# (b0, b1) = (297.635, 0.273)
# (b0, b1) = (354.664, 0.257)
# (b0, b1) = (329.076, 0.265)
# (b0, b1) = (298.102, 0.272)
# (b0, b1) = (386.928, 0.245)
# (b0, b1) = (280.135, 0.277)
# (b0, b1) = (364.904, 0.254)
# (b0, b1) = (357.105, 0.256)
# (b0, b1) = (380.481, 0.249)
# (b0, b1) = (294.923, 0.274)
# (b0, b1) = (376.237, 0.248)
# (b0, b1) = (342.568, 0.258)
# (b0, b1) = (243.352, 0.286)
# (b0, b1) = (300.383, 0.269)
# (b0, b1) = (374.702, 0.249)
# (b0, b1) = (248.084, 0.286)
# (b0, b1) = (425.310, 0.235)
# (b0, b1) = (364.600, 0.255)
# (b0, b1) = (278.441, 0.278)
# (b0, b1) = (232.914, 0.289)
# (b0, b1) = (371.579, 0.251)
# (b0, b1) = (306.798, 0.267)
# (b0, b1) = (382.855, 0.247)
# (b0, b1) = (340.304, 0.260)
# (b0, b1) = (327.776, 0.263)
# (b0, b1) = (305.429, 0.270)
# (b0, b1) = (346.631, 0.258)
# (b0, b1) = (319.189, 0.265)
# (b0, b1) = (293.189, 0.273)
# (b0, b1) = (440.673, 0.232)
# (b0, b1) = (394.391, 0.246)
# (b0, b1) = (294.099, 0.271)
# (b0, b1) = (279.071, 0.275)
# (b0, b1) = (336.638, 0.261)
# (b0, b1) = (324.205, 0.264)
# (b0, b1) = (404.553, 0.241)
# (b0, b1) = (371.740, 0.252)
# (b0, b1) = (308.659, 0.269)
# (b0, b1) = (296.618, 0.274)
# (b0, b1) = (251.494, 0.284)
# (b0, b1) = (379.842, 0.249)
# (b0, b1) = (318.299, 0.266)
# (b0, b1) = (297.687, 0.272)
# (b0, b1) = (299.296, 0.271)
# (b0, b1) = (302.124, 0.269)
# (b0, b1) = (369.439, 0.252)
# (b0, b1) = (303.623, 0.269)
# (b0, b1) = (352.573, 0.255)
# (b0, b1) = (218.548, 0.296)
# (b0, b1) = (280.150, 0.278)
# (b0, b1) = (339.872, 0.259)
# (b0, b1) = (295.827, 0.273)
# (b0, b1) = (290.517, 0.275)
# (b0, b1) = (284.896, 0.277)
# (b0, b1) = (303.600, 0.268)
# (b0, b1) = (311.378, 0.267)
# (b0, b1) = (340.095, 0.258)
# (b0, b1) = (327.212, 0.262)
# (b0, b1) = (452.340, 0.228)
# (b0, b1) = (321.530, 0.263)
# (b0, b1) = (321.391, 0.265)
# (b0, b1) = (315.115, 0.265)
# (b0, b1) = (315.960, 0.266)
# (b0, b1) = (323.668, 0.264)
# (b0, b1) = (336.384, 0.262)
# (b0, b1) = (318.264, 0.265)
# (b0, b1) = (454.376, 0.226)
# (b0, b1) = (295.093, 0.269)
# (b0, b1) = (315.558, 0.267)
# (b0, b1) = (335.459, 0.263)
# (b0, b1) = (276.819, 0.277)
# (b0, b1) = (225.930, 0.292)
# (b0, b1) = (287.997, 0.273)
# (b0, b1) = (330.732, 0.261)
# (b0, b1) = (267.546, 0.282)
# (b0, b1) = (385.783, 0.247)
# (b0, b1) = (395.479, 0.243)
# (b0, b1) = (306.056, 0.269)
# (b0, b1) = (269.728, 0.277)
# (b0, b1) = (359.747, 0.254)
# (b0, b1) = (330.074, 0.262)
# (b0, b1) = (344.596, 0.259)
# (b0, b1) = (377.635, 0.249)
# (b0, b1) = (286.209, 0.273)
# (b0, b1) = (304.186, 0.268)
# (b0, b1) = (296.744, 0.271)
# (b0, b1) = (329.138, 0.264)
# (b0, b1) = (353.546, 0.255)
# (b0, b1) = (366.611, 0.254)
# (b0, b1) = (391.864, 0.245)
# (b0, b1) = (284.925, 0.274)
# (b0, b1) = (334.083, 0.262)
# (b0, b1) = (254.436, 0.280)
# (b0, b1) = (385.346, 0.247)
# (b0, b1) = (309.121, 0.268)
# (b0, b1) = (280.676, 0.275)
# (b0, b1) = (397.326, 0.243)
# (b0, b1) = (325.593, 0.263)
# (b0, b1) = (313.551, 0.267)
# (b0, b1) = (243.665, 0.288)
# (b0, b1) = (336.741, 0.264)
# (b0, b1) = (303.146, 0.269)
# (b0, b1) = (302.557, 0.269)
# (b0, b1) = (414.084, 0.240)
# (b0, b1) = (306.855, 0.268)
# (b0, b1) = (227.065, 0.291)
# (b0, b1) = (269.528, 0.278)
# (b0, b1) = (338.792, 0.261)
# (b0, b1) = (339.089, 0.260)
# (b0, b1) = (313.469, 0.268)
# (b0, b1) = (259.299, 0.281)
# (b0, b1) = (334.005, 0.260)
# (b0, b1) = (276.302, 0.277)
# (b0, b1) = (381.480, 0.251)
# (b0, b1) = (344.901, 0.256)
# (b0, b1) = (296.620, 0.269)
# (b0, b1) = (332.579, 0.264)
# (b0, b1) = (315.354, 0.269)
# (b0, b1) = (303.146, 0.270)
# (b0, b1) = (356.372, 0.258)
# (b0, b1) = (370.684, 0.251)
# (b0, b1) = (406.864, 0.240)
# (b0, b1) = (351.784, 0.257)
# (b0, b1) = (158.326, 0.311)
# (b0, b1) = (271.246, 0.277)
# (b0, b1) = (412.235, 0.240)
# (b0, b1) = (286.779, 0.274)
# (b0, b1) = (302.189, 0.271)
# (b0, b1) = (366.968, 0.252)
# (b0, b1) = (268.789, 0.281)
# (b0, b1) = (393.955, 0.243)
# (b0, b1) = (287.867, 0.274)
# (b0, b1) = (345.353, 0.259)
# (b0, b1) = (404.443, 0.240)
# (b0, b1) = (352.226, 0.257)
# (b0, b1) = (342.638, 0.260)
# (b0, b1) = (362.459, 0.252)
# (b0, b1) = (379.956, 0.249)
# (b0, b1) = (386.446, 0.247)
# (b0, b1) = (281.525, 0.276)
# (b0, b1) = (403.078, 0.242)
# (b0, b1) = (387.660, 0.244)
# (b0, b1) = (317.400, 0.265)
# (b0, b1) = (367.080, 0.254)
# (b0, b1) = (335.895, 0.261)
# (b0, b1) = (452.773, 0.230)
# (b0, b1) = (394.887, 0.244)
# (b0, b1) = (245.912, 0.285)
# (b0, b1) = (273.521, 0.279)
# (b0, b1) = (338.955, 0.257)
# (b0, b1) = (277.675, 0.277)
# (b0, b1) = (346.504, 0.259)
# (b0, b1) = (419.408, 0.236)
# (b0, b1) = (352.352, 0.256)
# (b0, b1) = (331.828, 0.261)
# (b0, b1) = (325.714, 0.263)
# (b0, b1) = (309.528, 0.268)
# (b0, b1) = (268.487, 0.280)
# (b0, b1) = (343.401, 0.260)
# (b0, b1) = (289.198, 0.273)
# (b0, b1) = (330.318, 0.263)
# (b0, b1) = (371.986, 0.248)
# (b0, b1) = (306.810, 0.270)
# (b0, b1) = (353.767, 0.256)
# (b0, b1) = (386.966, 0.247)
# (b0, b1) = (328.582, 0.263)
# (b0, b1) = (289.926, 0.272)
# (b0, b1) = (202.316, 0.298)
# (b0, b1) = (404.485, 0.243)
# (b0, b1) = (290.563, 0.275)
# (b0, b1) = (348.407, 0.256)
# (b0, b1) = (277.702, 0.276)
# (b0, b1) = (266.360, 0.280)
# (b0, b1) = (318.299, 0.266)
# (b0, b1) = (283.364, 0.275)
# (b0, b1) = (325.746, 0.264)
# (b0, b1) = (262.879, 0.281)
# (b0, b1) = (327.874, 0.262)
# (b0, b1) = (258.464, 0.284)
# (b0, b1) = (326.746, 0.262)
# (b0, b1) = (451.699, 0.229)
# (b0, b1) = (336.298, 0.260)
# (b0, b1) = (244.761, 0.285)
# (b0, b1) = (408.896, 0.239)
# (b0, b1) = (283.010, 0.275)
# (b0, b1) = (310.302, 0.270)
# (b0, b1) = (297.227, 0.269)
# (b0, b1) = (284.713, 0.275)
# (b0, b1) = (318.688, 0.264)
# (b0, b1) = (353.788, 0.254)
# (b0, b1) = (304.765, 0.269)
# (b0, b1) = (328.378, 0.263)
# (b0, b1) = (305.138, 0.270)
# (b0, b1) = (309.949, 0.268)
# (b0, b1) = (315.565, 0.266)
# (b0, b1) = (259.087, 0.284)
# (b0, b1) = (349.403, 0.257)
# (b0, b1) = (332.824, 0.262)
# (b0, b1) = (311.061, 0.268)
# (b0, b1) = (327.627, 0.262)
# (b0, b1) = (362.665, 0.252)
# (b0, b1) = (301.679, 0.268)
# (b0, b1) = (353.913, 0.256)
# (b0, b1) = (236.001, 0.288)
# (b0, b1) = (262.971, 0.283)
# (b0, b1) = (205.000, 0.298)
# (b0, b1) = (307.247, 0.271)
# (b0, b1) = (376.461, 0.251)
# (b0, b1) = (335.230, 0.261)
# (b0, b1) = (435.965, 0.233)
# (b0, b1) = (335.830, 0.261)
# (b0, b1) = (320.908, 0.265)
# (b0, b1) = (334.072, 0.259)
# (b0, b1) = (291.040, 0.274)
# (b0, b1) = (315.752, 0.267)
# (b0, b1) = (304.718, 0.268)
# (b0, b1) = (312.907, 0.268)
# (b0, b1) = (355.027, 0.255)
# (b0, b1) = (279.701, 0.276)
# (b0, b1) = (319.472, 0.264)
# (b0, b1) = (393.247, 0.243)
# (b0, b1) = (331.291, 0.262)
# (b0, b1) = (408.468, 0.239)
# (b0, b1) = (327.563, 0.262)
# (b0, b1) = (281.213, 0.275)
# (b0, b1) = (318.138, 0.265)
# (b0, b1) = (344.185, 0.259)
# (b0, b1) = (280.826, 0.278)
# (b0, b1) = (297.394, 0.271)
# (b0, b1) = (310.283, 0.267)
# (b0, b1) = (441.756, 0.233)
# (b0, b1) = (323.562, 0.264)
# (b0, b1) = (280.202, 0.278)
# Bootstrap SE(b1): 0.01316
# Analytical SE(b1): 0.01291

# %% [markdown]
# ### TASK A6. Written questions
#
# Answer in the cell below.
#
# 1. The fitted slope carries physical units. State them and explain in one sentence what the slope
#    means for this dataset.
# 2. The value of $R^2$ obtained here is well below unity. Give two distinct reasons why a single
#    predictor cannot account for all of the variance in the response.
# 3. Suppose the head size were reported in cubic metres instead of cubic centimetres. State how
#    $b_0$, $b_1$, RMSE, and $R^2$ would each change.

# %% [markdown]
# ## ANSWER A6
#
# ### ANSWER 1
#
# The slope has units of **grams per cubic centimetre (g/cm³)** because brain weight is measured in grams and head size is measured in cubic centimetres.
#
# The slope means that **for every increase of 1 cm³ in head size, the predicted brain weight increases by about 0.26 grams**.
#
# ### ANSWER 2
#
# The value of **R²** is below 1 because one predictor cannot explain all the changes in brain weight.
#
# 1. **Other factors affect brain weight**, such as age, sex, body size, and genetics.
#
# 2. **Natural variation and measurement errors** also cause differences in brain weight, even when two people have similar head sizes.
#
# ### ANSWER 3
#
# If head size is reported in **cubic metres (m³)** instead of **cubic centimetres (cm³)**:
#
# * **b₀ (intercept):** remains the same.
# * **b₁ (slope):** becomes **1,000,000 times larger**.
# * **RMSE:** remains the same.
# * **R²:** remains the same.
#
# This is because changing the units of head size does not change the quality of the regression fit.

# %% [markdown]
# ---
# # Part B. Logistic regression
#
# ## Program 1. Preprocessing and classification on the Titanic dataset with `scikit-learn`
#
# ### Aim
#
# To prepare a dataset that contains missing values and categorical columns, and to fit and evaluate
# a logistic regression classifier on it.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

titanic_df = pd.read_csv("./datasets/titanic.csv")
titanic_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# ### TASK B1. Exploratory visualisation
#
# The helper below draws a single titled figure. Use it to produce the six plots listed in the
# comments.

# %%
def plot(title, plot_func, *args, **kwargs):
    plt.figure(figsize=(7, 4))
    plt.title(title)
    plot_func(*args, **kwargs)
    plt.show()


# TODO : produce the following six figures using the helper above
# 1. a heatmap of titanic_df.isnull() to reveal which columns carry missing values
# 2. a count plot of Survived split by Sex
# 3. a count plot of Survived split by Pclass
# 4. a histogram of Age, with the missing entries dropped
# 5. a histogram of Fare
# 6. a box plot of Age against Pclass

#1
plt.title("Heatmap of missing values")
sns.heatmap(titanic_df.isnull(),cbar = False, yticklabels=False)
plt.show()

#2
plt.title("Survived by Sex")
sns.countplot(data = titanic_df, x ="Survived", hue="Sex")
plt.show()

#3
plt.title("Survived by Pclass")
sns.countplot(data = titanic_df, x ="Survived", hue="Pclass")
plt.show()
#4
plt.title("Age Distribution")
sns.histplot(data = titanic_df["Age"].dropna(), bins = 30,kde = True)
plt.show()
#5
plt.title("Fare Distribution")
sns.histplot(data = titanic_df["Fare"], bins = 30,kde = True)
plt.show()
#6
plt.title("Age Vs Pclass")
sns.boxplot(data = titanic_df, x ="Pclass",y = "Age")
plt.show()

# %% [markdown]
# **ANSWER B1.** State which columns carry missing values, and describe in two or three sentences
# what the box plot of age against passenger class reveals.
#
# ANSWER : The columns that have missing values are Age, Cabin and Embarked The Cabin column has the missing values while Age has some missing entries and Embarked has only a few.
#
# The box plot of Age versus Passenger Class (Pclass) shows that passengers in class were generally older while passengers in 3rd class were younger. It also shows that the spread of ages is larger in class and that there are some outlies, in each passenger class.

# %% [markdown]
# ### TASK B2. Missing, categorical, and irrelevant columns
#
# Missing ages are filled with the mean age of the passenger class rather than with the mean of the
# whole column, because age and class are correlated. Complete the imputation, then encode the
# categorical columns and remove the columns that carry no predictive value.

# %%
# TODO 
# 1. build a dictionary mean_ages mapping each passenger class to the mean age within that class
# 2. complete impute_missing_age so that a missing age is replaced by the class mean
#    and an age that is already present is returned unchanged
# 3. apply it along axis 1 to the two columns Age and Pclass
# 4. redraw the missing value heatmap to confirm that the Age column is now complete

#1
mean_ages = titanic_df.groupby("Pclass")["Age"].mean().to_dict()

#2
def impute_missing_age(columns):
    age, p_class = columns
    if pd.isnull(age):
        return mean_ages[p_class]
    else:
        return age
    raise NotImplementedError("Task B2: complete impute_missing_age(), then delete this line")

#3
titanic_df["Age"] = titanic_df[["Age","Pclass"]].apply(impute_missing_age,axis=1)

#4
plt.figure(figsize=(7, 4))
plt.title("Missing Values After Age Imputation")
sns.heatmap(titanic_df.isnull(),cbar = False, yticklabels=False)
plt.show()

# %%
#TODO 
# 1. drop the Cabin column, which is missing for most passengers, then drop the remaining
#    rows that still contain a missing value
# 2. one-hot encode Sex and Embarked with pd.get_dummies, passing drop_first=True,
#    and concatenate the result to the frame
# 3. drop Name, PassengerId, Ticket, Sex, and Embarked
# 4. display the first five rows of the processed frame
# 1
titanic_df = titanic_df.drop("Cabin",axis = 1)
titanic_df = titanic_df.dropna()
#2
sex = pd.get_dummies(titanic_df["Sex"],drop_first=True)
embarked = pd.get_dummies(titanic_df["Embarked"],drop_first=True) 
titanic_df = pd.concat([titanic_df,sex,embarked],axis = 1)
#3
titanic_df = titanic_df.drop(["Name","PassengerId","Ticket","Sex","Embarked"],axis=1)
4
titanic_df.head()
# Out:
#    Survived  Pclass   Age  SibSp  Parch     Fare   male      Q      S
# 0         0       3  22.0      1      0   7.2500   True  False   True
# 1         1       1  38.0      1      0  71.2833  False  False  False
# 2         1       3  26.0      0      0   7.9250  False  False   True
# 3         1       1  35.0      1      0  53.1000  False  False   True
# 4         0       3  35.0      0      0   8.0500   True  False   True

# %% [markdown]
# **ANSWER B2.** Explain why `drop_first=True` is used when the categorical columns are encoded,
# and what would go wrong if all of the indicator columns were retained.
#
# ANSWER: We use `drop_first=True` to get rid of one column from each group of categories The other columns are enough to show all the categories.
#
# If we keep all the columns we can figure out one column from the other . That causes problems This is called the dummy variable trap multicollineari The dummy variable trap makes the model coefficients hard to understand and not reliable Multicollineari is an issue because it makes the model coefficients unstable
# ble

# %% [markdown]
# ### TASK B3. Fitting and evaluating the classifier
#
# Scale `Age` and `Fare` to the unit interval before fitting, so that the two columns of large
# numerical range do not dominate the optimisation. Fix `random_state` in the split so that your
# result is reproducible.

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.preprocessing import minmax_scale

# TODO 
# 1. rescale the Age and Fare columns with minmax_scale
# 2. separate the predictors X from the target y, which is the Survived column
# 3. split into training and test sets with test_size=0.3 and a fixed random_state
# 4. fit a LogisticRegression model and predict on the test set
# 5. print the classification report and the confusion matrix

#1
titanic_df["Age"] = minmax_scale(titanic_df["Age"])
titanic_df["Fare"] =  minmax_scale(titanic_df["Fare"])

#2
X = titanic_df.drop("Survived",axis = 1)
y = titanic_df["Survived"]
#3
X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=0.3,random_state=42)
#4
model = LogisticRegression()
model.fit(X_train, y_train)
#5
y_pred =model.predict(X_test)
#6
print(classification_report(y_test, y_pred))
print(confusion_matrix(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.83      0.83       167
#            1       0.72      0.72      0.72       100
#
#     accuracy                           0.79       267
#    macro avg       0.78      0.78      0.78       267
# weighted avg       0.79      0.79      0.79       267
#
# [[139  28]
#  [ 28  72]]

# %% [markdown]
# ### TASK B4. Interpretation
#
# Answer in the cell below.
#
# 1. Write out the confusion matrix you obtained and label the four entries as true positives, false
#    positives, true negatives, and false negatives.
# 2. Define precision and recall in words, and compute both by hand for the survivor class from your
#    confusion matrix. Confirm that your values match the classification report.
# 3. Rerun the split with three different values of `random_state` and record the accuracy each time.
#    Comment on the spread and on what it implies about reporting a single accuracy figure.

# %% [markdown]
# ## ANSWER B4
#
# ### 1. Confusion Matrix
#
# The confusion matrix obtained is:
#
# |              | Predicted 0 | Predicted 1 |
# | ------------ | ----------- | ----------- |
# | **Actual 0** | **139**     | **28**      |
# | **Actual 1** | **28**      | **72**      |
#
# The four entries are:
#
# * **True Negatives (TN)** = 139
# * **False Positives (FP)** = 28
# * **False Negatives (FN)** = 28
# * **True Positives (TP)** = 72
#
# ### 2. Precision and Recall for the Survivor Class
#
# **Precision** is the proportion of passengers predicted to survive who actually survived.
#
# $$
# \text{Precision} = \frac{TP}{TP + FP}
# $$
#
# Substituting the values:
#
# $$
# \text{Precision} = \frac{72}{72 + 28}
# = \frac{72}{100}
# = 0.72
# $$
#
# **Recall** is the proportion of passengers who actually survived and were correctly predicted by the model.
#
# $$
# \text{Recall} = \frac{TP}{TP + FN}
# $$
#
# Substituting the values:
#
# $$
# \text{Recall} = \frac{72}{72 + 28}
# = \frac{72}{100}
# = 0.72
# $$
#
# Therefore, for the survivor class:
#
# * **Precision = 0.72**
# * **Recall = 0.72**
#
# These calculated values match the classification report, which also gives **precision = 0.72** and **recall = 0.72** for class **1 (Survived)**.

# %%
## ANSWER 3
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score

s = [0, 42, 99]
for i in s:
    X_train, X_test, y_train, y_test = train_test_split(
        X, y, test_size=0.2, random_state=i
    )

    model = DecisionTreeClassifier(random_state=0)
    model.fit(X_train, y_train)
    
    y_pred = model.predict(X_test)
    accuracy = accuracy_score(y_test, y_pred)

    print(f"random_state = {i}, Accuracy = {accuracy:.3f}")
# Out:
# random_state = 0, Accuracy = 0.730
# random_state = 42, Accuracy = 0.770
# random_state = 99, Accuracy = 0.708

# %% [markdown]
# ## Answer 3
# The accuracy changes a little for values of random state This shows that how well the model performs depends on the train test split. So showing one accuracy number might not be trustworthy Using splits or cross validation gives a better idea of how the model really works.

# %% [markdown]
# ---
# ## Program 2. Logistic regression by gradient descent, compared with `scikit-learn`
#
# ### Aim
#
# To implement logistic regression through gradient descent on the log-likelihood, and to compare its
# accuracy with the library implementation on the Pima diabetes dataset.
#
# ### Theory
#
# $$
# \newcommand{\vect}{\mathbf}
# \text{Log-likelihood}, \quad LL = \sum_{i=1}^{m} y_i \log(p_i) + (1-y_i)\log(1-p_i)
# $$
#
# where
#
# $$
# p_i = p(\vect{x}_i, \vect{w}) = \frac{1}{1+e^{-\vect{w}^T\vect{x}_i}}
# $$
#
# Here $\vect{w} = (w_0, w_1, \dots, w_n)$ is the weight vector and
# $\vect{x}_i = (1, x_{i1}, x_{i2}, \dots, x_{in})$ is the $i$th input vector, the leading unit
# entry accounting for the intercept.
#
# The weights are chosen so that
#
# $$
# \max_{\vect{w}} LL = \min_{\vect{w}} (-LL)
# $$
#
# The gradient of the negative log-likelihood takes the compact form
#
# $$
# \frac{d(-LL)}{d\vect{w}} = \sum_{i=1}^{m}(p_i-y_i)\,\vect{x}_i = (\vect{p}-\vect{y})^T X
# $$
#
# so that the update step of gradient descent is
#
# $$
# \vect{w} := \vect{w} - \alpha\,(\vect{p}-\vect{y})^T X
# $$
#
# where $\alpha$ is the learning rate.

# %% [markdown]
# ### TASK B5. Implementing the classifier
#
# Complete the class below. No optimisation routine from a library may be used.

# %%
import numpy as np
import pandas as pd

# %%
class LogitRegression:
    """Binary logistic regression trained by full batch gradient descent."""

    def __init__(self, learning_rate, iterations):
        self.learning_rate = learning_rate
        self.iterations = iterations

    def p(self, X):
        """Return the predicted probability for a design matrix that already carries
        the leading column of ones."""
        # TODO (1 mark): return the logistic function of X @ self.w
        return 1/(1+np.exp(-X@self.w))
        raise NotImplementedError("Task B5: complete p(), then delete this line")

    def fit(self, X, y):
        m, n = X.shape
        X = np.hstack([np.ones((m, 1)), X])
        y = y.squeeze()
        self.w = np.zeros(n + 1)

        # TODO (2 marks): repeat the update step self.iterations times,
        # then return self
        for i in range(self.iterations):
            prob = self.p(X)
            gra = (X.T@(prob - y))/m
            self.w = self.w-self.learning_rate*gra
        return self    
        
        raise NotImplementedError("Task B5: complete fit(), then delete this line")

    def predict(self, X):
        """Return the predicted class label, 0 or 1, for each row of X."""
        m = X.shape[0]
        X = np.hstack([np.ones((m, 1)), X])

        # TODO (1 mark): threshold the predicted probability at 0.5
        return (self.p(X) >= 0.5).astype(int)
        raise NotImplementedError("Task B5: complete predict(), then delete this line")

# %%
from sklearn.preprocessing import minmax_scale
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

diabetes_df = pd.read_csv("./datasets/diabetes.csv")
X = minmax_scale(diabetes_df.iloc[:, :-1].values)
y = diabetes_df.iloc[:, -1:].values.reshape(-1)
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=1/3, random_state=6
)
print(X_train.shape, X_test.shape)
# Out:
# (512, 8) (256, 8)

# %%
def compute_accuracy(model, X_test, y_test):
    y_hat = model.predict(X_test)
    return (y_hat == y_test).mean() * 100


# TODO: fit both your own LogitRegression, with learning_rate=0.1 and iterations=1000,
# and the library LogisticRegression, then print the test accuracy of each
models = [
    LogitRegression(learning_rate=0.1, iterations=1000),
    LogisticRegression(),
]
for model in models:
    model.fit(X_train,y_train)
    accuracy = compute_accuracy(model, X_test, y_test)
    print(type(model).__name__, "Accuracy:", round(accuracy, 2),"%")
# Out:
# LogitRegression Accuracy: 74.22 %
# LogisticRegression Accuracy: 78.91 %

# %% [markdown]
# ### TASK B6. Effect of the learning rate
#
# Train your implementation with learning rates of 0.001, 0.01, 0.1, and 1.0, holding the number of
# iterations fixed at 1000. Tabulate the test accuracy against the learning rate and comment in two
# or three sentences on what you observe at the two extremes.

# %%
# TODO : loop over the four learning rates and report the test accuracy of each
lr =  [0.001, 0.01, 0.1, 1.0]
print("Learning Rate                          Test Accuracy")
for l in lr:
    model = LogitRegression(learning_rate=l, iterations=1000)
    model.fit(X_train, y_train)
    accuracy = compute_accuracy(model, X_test, y_test)
    print(lr, "                ", round(accuracy, 2), "%")
# Out:
# Learning Rate                          Test Accuracy
# [0.001, 0.01, 0.1, 1.0]                  67.58 %
# [0.001, 0.01, 0.1, 1.0]                  67.58 %
# [0.001, 0.01, 0.1, 1.0]                  74.22 %
# [0.001, 0.01, 0.1, 1.0]                  77.34 %

# %% [markdown]
# **ANSWER B6.**
#
# When the learning rate is really small like 0.001 the model learns at a slow pace This means that after 1000 iterations the model may not find the best solution As a result the accuracy of the model can be lower.
# On the hand if the learning rate is very large like 1.0 the updates are too big The model learning rate of 1.0 can cause the model to overshoot the optimum which's not good for the accuracy of the model either.
# The model learning rate of 0.01 or 0.1 is usually just right The model learning rate like this gives the performance because it is not too slow and not too fast.
