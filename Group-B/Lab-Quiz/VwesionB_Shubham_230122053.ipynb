# %%
#Q1

reactions=["CC(=O)O.OCC>[H+].[Cl-]>CC(=O)OCC.O","C=C.[H][H]>[Pd]>CC","c1ccccc1.O=[N+]([O-])O>>c1ccccc1[N+](=O)[O-].O",]

def arse_reaction(rxn):
  for r in rxn:
    str = r
    n=len(str)
    t=0
    dot=0
    if n==0:
      return {}
    for i in range(n):
      if str[i]==str[i+1] && str[i]=='>':
        return {};
      if str[i]=='>':
        t=t+1
      if str[i]=='.':
        dot=dot+1

    if t==2 :
      print("number of elemt is ", dot ,str)


  print("Ist Reactin is Esterficaton reaction")
  print("Empty ragent means the reaction doesn't require any reagent , it is reducing reaction")

# %%
#Q3
import numpy as np

A=np.zeros((4,4))
A=np.array([[0,1,0,0],[1,0,1,0],[0,1,0,1],[0,0,1,0]])

print("egenvalue are 4 , -4 ,2 ,-2")

#Delocalsisation energy of Butadience is less than benzene as benzen has very delocalisation due to more conjucation and its aromaticity character adds too.

# %%
# Q2

#2C2H6+7O2 -> 4CO2 + 6H2O

#x1=2 , x2=7, x3=4, x4=6

#x=np.array([[4,0,-4,0],[12,0,0,-12],[0,14,]])
import numpy as np

x=np.array([2,7,4,6])  #1*4
E=np.array([[2.,0.,-1.,0.],[6.,0.,0.,-2.],[0.,2.,-2.-1,]]) #3*4

# %%
#Q5
import numpy as np
X=np.array([[78.1,2.3],[92.1,1.7],[106.2,2.8],[120.2,2.0],[134.2,3.1],[148.2,2.4]])
x_mean_mm=np.mean(x[0])
x_mean_dm=np.mean(x[1])
x_std_mm=np.sum(X-x_mean_mm)/6
x_std_dm=np.sum(X-x_mean_dm)/6

for i in range(6):
  X[i][0]=X[i][0]/x_std_mm
  X[i][1]=X[i][1]/x_std_dm

# %%
#Q4
